# %% [markdown]
# # FLARE23 解压与预处理（Colab）
#
# **压缩包**：`/content/drive/MyDrive/dataset/pretrain/FLARE23/download` 下的 **part1–part7** 共 7 个 `.zip`（命名建议 `part1.zip` … `part7.zip`，或 `part1*.zip` 形式）。
#
# **解压目标**：分别解压到 **`unzip/part1`** … **`unzip/part7`**（与 `download` 同级的 `unzip` 目录）。
#
# **预处理**：与 `colab_flare22_preprocess.ipynb`、`proc_spatial_sequence` 一致 — 每个体积 50/33 个 `128³` patch，`Resize` + `ScaleIntensityRangePercentiles(1, 99.9)`；在 `unzip/` 下递归收集 `.nii`/`.nii.gz`，跳过 `__MACOSX`。输出扁平保存到 **`npy/`**，文件名中含 **`part1`…`part7`** 前缀以免分卷重复。
#
# 解压与预处理分成多块，便于在 Colab 上分批运行、断点续跑。

# %%
# Cell 1: 挂载 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Cell 2: 安装依赖
# !pip install -q nibabel monai tqdm

# %%
# Cell 3: 解压 part1
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part1'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part1 完成')

# %%
# Cell 4: 解压 part2
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part2'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part2 完成')

# %%
# Cell 5: 解压 part3
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part3'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part3 完成')

# %%
# Cell 6: 解压 part4
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part4'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part4 完成')

# %%
# Cell 7: 解压 part5
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part5'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part5 完成')

# %%
# Cell 8: 解压 part6
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part6'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part6 完成')

# %%
# Cell 9: 解压 part7
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part7'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part7 完成')

# %%
# Cell 10: FLARE23 预处理（与 FLARE22 Colab 逻辑一致；ds_name 含 unzip 下 part 目录名）
import os
import random
import numpy as np
import nibabel as nib
from monai.transforms import Compose, Resize, ScaleIntensityRangePercentiles
from tqdm import tqdm

DRIVE_UNZIP = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
DRIVE_SAVE_ROOT = '/content/drive/MyDrive/dataset/pretrain/FLARE23/npy'

PATCH_NUM = 50
PATCH_SIZE_LIST = [(128, 128, 128)]
TAR_IMG_SIZE = [128, 128, 128]
START_INDEX = 0


def flare23_ds_name(image_file):
    parts = image_file.replace('\\', '/').split('/')
    if 'unzip' in parts:
        i = parts.index('unzip')
        if i + 1 < len(parts):
            return parts[i + 1]
    return parts[-3] if len(parts) >= 3 else 'FLARE23'


def cut_patch(img_array, patch_size):
    img_shape = img_array.shape
    size_z, size_y, size_x = patch_size
    center_x_min, center_x_max = size_x // 2, img_shape[2] - size_x // 2 - 1
    center_y_min, center_y_max = size_y // 2, img_shape[1] - size_y // 2 - 1
    center_z_min, center_z_max = size_z // 2, img_shape[0] - size_z // 2 - 1
    if center_x_min >= center_x_max:
        x1, x2 = 0, img_shape[2]
    else:
        center_x = random.randint(center_x_min, center_x_max)
        x1, x2 = center_x - size_x // 2, center_x + size_x // 2
    if center_y_min >= center_y_max:
        y1, y2 = 0, img_shape[1]
    else:
        center_y = random.randint(center_y_min, center_y_max)
        y1, y2 = center_y - size_y // 2, center_y + size_y // 2
    if center_z_min >= center_z_max:
        z1, z2 = 0, img_shape[0]
    else:
        center_z = random.randint(center_z_min, center_z_max)
        z1, z2 = center_z - size_z // 2, center_z + size_z // 2
    img_patch = img_array[z1:z2, y1:y2, x1:x2]
    return img_patch, [z1, z2, y1, y2, x1, x2]


def load_nii_data(nii_file):
    nii_data = nib.load(nii_file)
    return nii_data.get_fdata(), nii_data.affine


def load_and_patch_transforms(img, tar_img_size):
    transforms = Compose([
        Resize(spatial_size=(tar_img_size[0], tar_img_size[1], tar_img_size[2]), mode='trilinear'),
        ScaleIntensityRangePercentiles(lower=1., upper=99.9, b_min=0.0, b_max=1.0, clip=True, relative=False, channel_wise=False),
    ])
    return transforms(img)


def cut_and_save_one_volume_flare23(image_file, patch_size_list, patch_num, save_root, start_index, tar_img_size):
    image, affine = load_nii_data(image_file)
    ds_name = flare23_ds_name(image_file)
    path_parts = image_file.replace('\\', '/').split('/')
    nii_id = path_parts[-1].split('.nii.gz')[0].split('.nii')[0].split('.mha')[0]

    if len(image.shape) == 4:
        return []
    images = [image]
    n, patch_path_list = 0, []

    for image_index, image in enumerate(images):
        image = image.transpose((2, 1, 0))
        _patch_num = int(patch_num / 1.5) if image.shape[0] < patch_size_list[0][2] else patch_num
        for i in range(_patch_num):
            n += 1
            patch_size = random.choice(patch_size_list)
            image_patch, _ = cut_patch(image, patch_size)
            image_patch = image_patch.transpose((2, 1, 0))
            image_patch = load_and_patch_transforms(np.expand_dims(image_patch, 0), tar_img_size).numpy()[0, ...]
            save_name = os.path.join(save_root, '%s_%s_%s_%d.nii.gz' % (ds_name, nii_id, image_index, start_index + n))
            patch_path_list.append(save_name)
            np.save(save_name.replace('.nii.gz', '.npy'), image_patch)
    return patch_path_list


def collect_flare23_nii_files(unzip_root):
    out = []
    if not os.path.isdir(unzip_root):
        return out
    for dirpath, _, files in os.walk(unzip_root):
        if '__MACOSX' in dirpath.replace('\\', '/'):
            continue
        for f in files:
            lower = f.lower()
            if lower.endswith('.nii.gz') or lower.endswith('.nii'):
                out.append(os.path.join(dirpath, f))
    return sorted(out)


os.makedirs(DRIVE_SAVE_ROOT, exist_ok=True)
data_list = collect_flare23_nii_files(DRIVE_UNZIP)
print(f'unzip root: {DRIVE_UNZIP}')
print(f'found {len(data_list)} nii / nii.gz')

if len(data_list) == 0:
    print('未找到文件；请确认已解压 part1–part7 到 unzip/。')
else:
    patch_list_all = []
    for i, path in enumerate(tqdm(data_list, desc='preprocess')):
        patch_list = cut_and_save_one_volume_flare23(path, PATCH_SIZE_LIST, PATCH_NUM, DRIVE_SAVE_ROOT, START_INDEX, TAR_IMG_SIZE)
        patch_list_all += patch_list
        if (i + 1) % 20 == 0:
            print(f'[{i+1}/{len(data_list)}] {path} -> {len(patch_list)} npy')
    print(f'\n完成。共 {len(patch_list_all)} 个 npy -> {DRIVE_SAVE_ROOT}')

# %%
# Cell 11 (可选): 生成 train_patch_spatial.txt 用于 pretrain
list_save_dir = os.path.join(os.path.dirname(DRIVE_SAVE_ROOT), 'pretrain_lists')
os.makedirs(list_save_dir, exist_ok=True)
npy_files = sorted([os.path.join(DRIVE_SAVE_ROOT, f) for f in os.listdir(DRIVE_SAVE_ROOT) if f.endswith('.npy')])
with open(os.path.join(list_save_dir, 'train_patch_spatial.txt'), 'w') as f:
    f.write('\n'.join(npy_files))
print(f'train_patch_spatial.txt -> {list_save_dir}')
