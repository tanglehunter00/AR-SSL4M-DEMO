# %% [markdown]
# # FLARE23 解压与预处理（Colab → GCS）
#
# **压缩包**：`/content/drive/MyDrive/dataset/pretrain/FLARE23/download` 下 **part1–part7** 共 7 个 `.zip`。
#
# **解压**：分别解压到 `unzip/part1` … `unzip/part7`。若解压后为 **`unzip/partN/partN/.../*.nii.gz`** 的嵌套结构，预处理会从内层 **`partN`** 开始递归收集（与 FLARE23 分卷一致）。
#
# **输出**：预处理结果写入 **`gs://flare23/part1`** … **`gs://flare23/part7`**（在 Colab 中通过 **gcsfuse** 挂载到本地目录后 `np.save`）。
#
# **预处理**：与 `colab_flare22_preprocess.ipynb` / `colab_abdomenct1k_preprocess.ipynb` 相同 — 每例 **50** 个 patch（深度维 \<128 时为 **33**，即 `int(50/1.5)`），**128³**，`Resize` + `ScaleIntensityRangePercentiles(1, 99.9)`。
#
# 运行顺序：挂载 Drive → 依赖 → 解压（按需）→ **GCS 认证与挂载** → **预处理函数定义** → **7 个单元依次处理 part1–part7**。

# %%
# Cell 1: 挂载 Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2: 安装依赖
# !pip install -q nibabel monai tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 37.4 MB/s eta 0:00:00

# %%
# Cell 3: 解压 part1
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part1'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part1 完成')

# %%
# Cell 4: 解压 part2
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part2'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part2 完成')

# %%
# Cell 5: 解压 part3
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part3'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part3 完成')

# %%
# Cell 6: 解压 part4
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part4'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part4 完成')

# %%
# Cell 7: 解压 part5
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part5'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part5 完成')

# %%
# Cell 8: 解压 part6
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part6'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part6 完成')

# %%
# Cell 9: 解压 part7
import glob
import os
import zipfile

DOWNLOAD_DIR = '/content/drive/MyDrive/dataset/pretrain/FLARE23/download'
UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
PART = 'part7'

os.makedirs(os.path.join(UNZIP_BASE, PART), exist_ok=True)
cand = os.path.join(DOWNLOAD_DIR, f'{PART}.zip')
if not os.path.isfile(cand):
    matches = sorted(glob.glob(os.path.join(DOWNLOAD_DIR, f'{PART}*.zip')))
    if not matches:
        raise FileNotFoundError(f'未找到 {PART} 的 zip，请检查 {DOWNLOAD_DIR}')
    cand = matches[0]
out_dir = os.path.join(UNZIP_BASE, PART)
print(f'解压 {cand} -> {out_dir}')
with zipfile.ZipFile(cand, 'r') as z:
    z.extractall(out_dir)
print('part7 完成')

# %%
# Cell 10: GCS 认证、项目与挂载（gcsfuse）
import os
import shutil
import subprocess

from google.colab import auth

auth.authenticate_user()

PROJECT_ID = 'brats-preprocess'
GCS_BRATS_BUCKET = 'gs://flare23'
BUCKET_NAME = GCS_BRATS_BUCKET.replace('gs://', '').strip('/')
GCS_MOUNT = '/content/gcs_flare23'

# !gcloud config set project {PROJECT_ID}


def _ubuntu_codename():
    if shutil.which('lsb_release'):
        r = subprocess.run(['lsb_release', '-cs'], capture_output=True, text=True)
        if r.returncode == 0 and r.stdout.strip():
            return r.stdout.strip()
    try:
        with open('/etc/os-release', encoding='utf-8') as f:
            for line in f:
                if line.startswith('VERSION_CODENAME='):
                    return line.split('=', 1)[1].strip().strip('"')
    except OSError:
        pass
    return 'jammy'


def ensure_gcsfuse():
    p = shutil.which('gcsfuse')
    if p:
        print('gcsfuse:', p)
        return p
    print('未检测到 gcsfuse：添加 Google gcsfuse apt 源并安装…')
    subprocess.run(['apt-get', 'update', '-qq'], check=False)
    subprocess.run(
        ['apt-get', 'install', '-y', '-qq', 'ca-certificates', 'curl', 'gnupg', 'lsb-release'],
        check=False,
    )
    codename = _ubuntu_codename()
    with open('/etc/apt/sources.list.d/gcsfuse.list', 'w', encoding='utf-8') as f:
        f.write(
            f'deb https://packages.cloud.google.com/apt gcsfuse-{codename} main\n'
        )
    subprocess.run(
        'curl -fsSL https://packages.cloud.google.com/apt/doc/apt-key.gpg | apt-key add -',
        shell=True,
        check=False,
    )
    subprocess.run(['apt-get', 'update', '-qq'], check=False)
    subprocess.run(['apt-get', 'install', '-y', '-qq', 'gcsfuse'], check=False)
    p = shutil.which('gcsfuse')
    if p:
        print('gcsfuse 已通过 apt 安装:', p)
        return p
    print('apt 未装上 gcsfuse，尝试 GitHub .deb（任选其一成功即可）…')
    deb = '/tmp/gcsfuse_amd64.deb'
    urls = [
        'https://github.com/GoogleCloudPlatform/gcsfuse/releases/download/v2.4.1/gcsfuse_2.4.1_amd64.deb',
        'https://github.com/GoogleCloudPlatform/gcsfuse/releases/download/v1.2.0/gcsfuse_1.2.0_amd64.deb',
    ]
    for url in urls:
        r = subprocess.run(['curl', '-fL', url, '-o', deb], capture_output=True, text=True)
        if r.returncode != 0:
            print('下载跳过:', url)
            continue
        subprocess.run(['dpkg', '-i', deb], check=False)
        subprocess.run(['apt-get', 'install', '-f', '-y', '-qq'], check=False)
        p = shutil.which('gcsfuse')
        if p:
            print('gcsfuse 已通过 .deb 安装:', p)
            return p
    raise RuntimeError(
        '无法安装 gcsfuse（默認源无包且 .deb 下载失败）。可改用：预处理写本地目录后 '
        '`gsutil -m cp -r` 上传到 gs://flare23/partN，或换用标准 Colab 运行时。'
    )


gcsfuse_bin = ensure_gcsfuse()

os.makedirs(GCS_MOUNT, exist_ok=True)
subprocess.run('fusermount -u /content/gcs_flare23 2>/dev/null || true', shell=True)
subprocess.run('umount -l /content/gcs_flare23 2>/dev/null || true', shell=True)

r = subprocess.run(
    [gcsfuse_bin, '--implicit-dirs', BUCKET_NAME, GCS_MOUNT],
    capture_output=True,
    text=True,
)
print(r.stdout or '', r.stderr or '', sep='')
if r.returncode != 0:
    raise RuntimeError(
        'gcsfuse 挂载失败。请确认对本账号授予桶读写权限，且桶名正确。也可改为本机先写 Drive 再用 gsutil 批量上传。'
    )

print(f'已挂载 {GCS_BRATS_BUCKET} -> {GCS_MOUNT}')
# !ls -la {GCS_MOUNT} | head
# Out:
# [environment: untagged] Read more to tag: g.co/cloud/project-env-tag.
# Updated property [core/project].
# 未检测到 gcsfuse：添加 Google gcsfuse apt 源并安装…
# gcsfuse 已通过 apt 安装: /usr/bin/gcsfuse
# {"timestamp":{"seconds":1778270377,"nanos":796161211},"severity":"INFO","message":"Start gcsfuse/3.9.0 (Go version go1.26.2) for app \"\" using mount point: /content/gcs_flare23\n","mount-id":"flare23-238e7eeb"}
# {"timestamp":{"seconds":1778270377,"nanos":796273133},"severity":"INFO","message":"GCSFuse Config","mount-id":"flare23-238e7eeb","CLI Flags":{"implicit-dirs":"true"}}
# ...

# %%
# Cell 11: FLARE23 预处理公共逻辑（与 FLARE22 Colab 一致；输出目录 = GCS 挂载点下的 partN）
import os
import random

import nibabel as nib
import numpy as np
from monai.transforms import Compose, Resize, ScaleIntensityRangePercentiles
from tqdm import tqdm

UNZIP_BASE = '/content/drive/MyDrive/dataset/pretrain/FLARE23/unzip'
GCS_MOUNT = '/content/gcs_flare23'
GCS_BRATS_BUCKET = 'gs://flare23'

PATCH_NUM = 50
PATCH_SIZE_LIST = [(128, 128, 128)]
TAR_IMG_SIZE = [128, 128, 128]
START_INDEX = 0


def flare23_nii_root(unzip_base, part):
    """支持 unzip/partN/partN/... 或单层 unzip/partN/...。"""
    inner = os.path.join(unzip_base, part, part)
    if os.path.isdir(inner):
        return inner
    return os.path.join(unzip_base, part)


def cut_patch(img_array, patch_size):
    img_shape = img_array.shape
    size_z, size_y, size_x = patch_size
    center_x_min, center_x_max = size_x // 2, img_shape[2] - size_x // 2 - 1
    center_y_min, center_y_max = size_y // 2, img_shape[1] - size_y // 2 - 1
    center_z_min, center_z_max = size_z // 2, img_shape[0] - size_z // 2 - 1
    if center_x_min >= center_x_max:
        x1, x2 = 0, img_shape[2]
    else:
        center_x = random.randint(center_x_min, center_x_max)
        x1, x2 = center_x - size_x // 2, center_x + size_x // 2
    if center_y_min >= center_y_max:
        y1, y2 = 0, img_shape[1]
    else:
        center_y = random.randint(center_y_min, center_y_max)
        y1, y2 = center_y - size_y // 2, center_y + size_y // 2
    if center_z_min >= center_z_max:
        z1, z2 = 0, img_shape[0]
    else:
        center_z = random.randint(center_z_min, center_z_max)
        z1, z2 = center_z - size_z // 2, center_z + size_z // 2
    img_patch = img_array[z1:z2, y1:y2, x1:x2]
    return img_patch, [z1, z2, y1, y2, x1, x2]


def load_nii_data(nii_file):
    nii_data = nib.load(nii_file)
    return nii_data.get_fdata(), nii_data.affine


def load_and_patch_transforms(img, tar_img_size):
    transforms = Compose([
        Resize(spatial_size=(tar_img_size[0], tar_img_size[1], tar_img_size[2]), mode='trilinear'),
        ScaleIntensityRangePercentiles(lower=1., upper=99.9, b_min=0.0, b_max=1.0, clip=True, relative=False, channel_wise=False),
    ])
    return transforms(img)


def cut_and_save_one_volume_flare23(image_file, part_tag, patch_size_list, patch_num, save_root, start_index, tar_img_size):
    image, _affine = load_nii_data(image_file)
    ds_name = part_tag
    path_parts = image_file.replace('\\', '/').split('/')
    nii_id = path_parts[-1].split('.nii.gz')[0].split('.nii')[0].split('.mha')[0]

    if len(image.shape) == 4:
        return []
    images = [image]
    n, patch_path_list = 0, []

    for image_index, image in enumerate(images):
        image = image.transpose((2, 1, 0))
        _patch_num = int(patch_num / 1.5) if image.shape[0] < patch_size_list[0][2] else patch_num
        for i in range(_patch_num):
            n += 1
            patch_size = random.choice(patch_size_list)
            image_patch, _ = cut_patch(image, patch_size)
            image_patch = image_patch.transpose((2, 1, 0))
            image_patch = load_and_patch_transforms(np.expand_dims(image_patch, 0), tar_img_size).numpy()[0, ...]
            save_name = os.path.join(save_root, '%s_%s_%s_%d.nii.gz' % (ds_name, nii_id, image_index, start_index + n))
            patch_path_list.append(save_name)
            np.save(save_name.replace('.nii.gz', '.npy'), image_patch)
    return patch_path_list


def collect_nii_under_root(unzip_root):
    out = []
    if not os.path.isdir(unzip_root):
        return out
    for dirpath, _, files in os.walk(unzip_root):
        if '__MACOSX' in dirpath.replace('\\', '/'):
            continue
        for f in files:
            lower = f.lower()
            if lower.endswith('.nii.gz') or lower.endswith('.nii'):
                out.append(os.path.join(dirpath, f))
    return sorted(out)


def process_flare23_part(part):
    nii_root = flare23_nii_root(UNZIP_BASE, part)
    save_root = os.path.join(GCS_MOUNT, part)
    os.makedirs(save_root, exist_ok=True)
    data_list = collect_nii_under_root(nii_root)
    print(f'[{part}] NIfTI 根: {nii_root}')
    print(f'[{part}] 输出: {save_root}  （对应 {GCS_BRATS_BUCKET}/{part}/）')
    print(f'[{part}] 共 {len(data_list)} 个 .nii / .nii.gz')
    if len(data_list) == 0:
        print(f'[{part}] 跳过：无文件。')
        return
    patch_list_all = []
    for i, path in enumerate(tqdm(data_list, desc=part)):
        patch_list = cut_and_save_one_volume_flare23(
            path, part, PATCH_SIZE_LIST, PATCH_NUM, save_root, START_INDEX, TAR_IMG_SIZE
        )
        patch_list_all += patch_list
        if (i + 1) % 20 == 0:
            print(f'[{part}][{i+1}/{len(data_list)}] {path} -> {len(patch_list)} npy')
    print(f'[{part}] 完成: {len(patch_list_all)} 个 npy')

# %%
# Cell 12: 预处理 part1 -> GCS part1
process_flare23_part('part1')

# %%
# Cell 13: 预处理 part2 -> GCS part2
process_flare23_part('part2')

# %%
# Cell 14: 预处理 part3 -> GCS part3
process_flare23_part('part3')

# %%
# Cell 15: 预处理 part4 -> GCS part4
process_flare23_part('part4')

# %%
# Cell 16: 预处理 part5 -> GCS part5
process_flare23_part('part5')

# %%
# Cell 17: 预处理 part6 -> GCS part6
process_flare23_part('part6')
# Out:
# [part6] NIfTI 根: /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part6/part6
# [part6] 输出: /content/gcs_flare23/part6  （对应 gs://flare23/part6/）
# [part6] 共 450 个 .nii / .nii.gz
# part6:   4%|▍         | 20/450 [11:58<4:04:38, 34.14s/it]
# [part6][20/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part6/part6/FLARE23_3220_0000.nii.gz -> 50 npy
# part6:   9%|▉         | 40/450 [25:01<3:45:13, 32.96s/it]
# [part6][40/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part6/part6/FLARE23_3240_0000.nii.gz -> 50 npy
# part6:  13%|█▎        | 60/450 [36:09<3:39:22, 33.75s/it]
# [part6][60/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part6/part6/FLARE23_3260_0000.nii.gz -> 50 npy
# part6:  18%|█▊        | 80/450 [47:43<3:25:41, 33.36s/it]
# [part6][80/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part6/part6/FLARE23_3280_0000.nii.gz -> 50 npy
# part6:  22%|██▏       | 100/450 [59:18<3:24:43, 35.09s/it]
# ...

# %%
# Cell 18: 预处理 part7 -> GCS part7
process_flare23_part('part7')
# Out:
# [part7] NIfTI 根: /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part7/part7
# [part7] 输出: /content/gcs_flare23/part7  （对应 gs://flare23/part7/）
# [part7] 共 450 个 .nii / .nii.gz
# part7:   4%|▍         | 20/450 [07:59<2:53:19, 24.19s/it]
# [part7][20/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part7/part7/FLARE23Ts_0020_0000.nii.gz -> 33 npy
# part7:   9%|▉         | 40/450 [16:46<3:03:22, 26.84s/it]
# [part7][40/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part7/part7/FLARE23Ts_0040_0000.nii.gz -> 50 npy
# part7:  13%|█▎        | 60/450 [27:07<2:44:13, 25.27s/it]
# [part7][60/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part7/part7/FLARE23Ts_0060_0000.nii.gz -> 33 npy
# part7:  18%|█▊        | 80/450 [36:51<2:45:03, 26.77s/it]
# [part7][80/450] /content/drive/MyDrive/dataset/pretrain/FLARE23/unzip/part7/part7/FLARE23Ts_0080_0000.nii.gz -> 33 npy
# part7:  22%|██▏       | 100/450 [44:38<2:09:52, 22.27s/it]
# ...

# %%
# Cell 19 (可选): 用 gsutil 粗查 GCS 上各 part 前缀下的对象条数
# !gcloud config set project brats-preprocess
import subprocess

for p in ['part1', 'part2', 'part3', 'part4', 'part5', 'part6', 'part7']:
    r = subprocess.run(
        ['gsutil', 'ls', f'gs://flare23/{p}/'],
        capture_output=True, text=True,
    )
    lines = [x for x in r.stdout.splitlines() if x.strip().endswith('.npy')]
    print(f'{p}: {len(lines)} .npy (前缀列目录；错误时看 stderr)')
    if r.returncode != 0 and r.stderr:
        print(r.stderr[:500])
